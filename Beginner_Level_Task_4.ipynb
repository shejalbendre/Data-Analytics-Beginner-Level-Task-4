# %% [markdown]
# <a href="https://colab.research.google.com/github/shejalbendre/Data-Analytics-Beginner-Level-Task-4/blob/main/Beginner_Level_Task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LetsGrowMore**
#
# **Author - Shejal Sanjay Bendre**
#
# **Data Science Intern**
#
# **Beginner Level Task 4 - Image to Pencil Sketch with Python**
#
# Import Required Libraries

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
#Original Image
image=cv2.imread("/content/sample_data/CAR.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=570x380 at 0x7F176A46FA50>

# %%
#grey Scale Image
grey_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) 
cv2_imshow(grey_image)
# Out:
# <PIL.Image.Image image mode=L size=570x380 at 0x7F176A385F90>

# %% [markdown]
# Inverting the grey scale image

# %%
#inverted Image
inverted_image = cv2.bitwise_not(grey_image)  
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=570x380 at 0x7F176A3A35D0>

# %% [markdown]
# Image Smoothing

# %%
#image smoothing
image_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(image_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=570x380 at 0x7F176A385E10>

# %% [markdown]
# Pencil sketch

# %%
def pencil_sketch(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
#pencil sketch
pencil_sketch=pencil_sketch(grey_image,image_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=570x380 at 0x7F176A385250>

# %% [markdown]
# Showing Original Image and the Pencil Sketch

# %%
cv2_imshow(image)
print("")
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=570x380 at 0x7F176A3B3E50>
# <PIL.Image.Image image mode=L size=570x380 at 0x7F176A3B3A50>

# %% [markdown]
# **Thank You!!!**
